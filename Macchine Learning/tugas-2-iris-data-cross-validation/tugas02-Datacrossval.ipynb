# %% [markdown]
# # MUHAMMAD KANZOON MAR
# ## 19/442479/PA/19228
#
# Data Cross Validation

# %%
import pandas as pd

# %%
iris = pd.read_csv('iris.csv')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print('Unique species = ' , iris.species.unique(), '\n')
print(iris.species.value_counts(), '\n')
print(iris.info())
# Out:
# Unique species =  ['setosa' 'versicolor' 'virginica']
#
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# ## Without function implementation

# %%
irisfolded=[]

def foldnsplit(data,i, j):
  n=len(data)
  return data[n*(i-1)//j : n*i//j]

for i in range(0,4):
  irisfolded.append(foldnsplit(iris, i+1, 3))

irisfolded
# Out:
# [    sepal_length  sepal_width  petal_length  petal_width species
#  0            5.1          3.5           1.4          0.2  setosa
#  1            4.9          3.0           1.4          0.2  setosa
#  2            4.7          3.2           1.3          0.2  setosa
#  3            4.6          3.1           1.5          0.2  setosa
#  4            5.0          3.6           1.4          0.2  setosa
#  5            5.4          3.9           1.7          0.4  setosa
#  6            4.6          3.4           1.4          0.3  setosa
#  7            5.0          3.4           1.5          0.2  setosa
#  8            4.4          2.9           1.4          0.2  setosa
#  9            4.9          3.1           1.5          0.1  setosa
#  10           5.4          3.7           1.5          0.2  setosa
#  11           4.8          3.4           1.6          0.2  setosa
#  12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
def traintestfold(data):
    train, test = [], []
    cross_val={'train': train, 'test': test}
    for i, tested in enumerate(data):
        train.append(data[:i] + data[i+1:])
        test.append(tested)
    
    return train, test

train, test = traintestfold(irisfolded)

# %%
train
# Out:
# [[    sepal_length  sepal_width  petal_length  petal_width     species
#   50           7.0          3.2           4.7          1.4  versicolor
#   51           6.4          3.2           4.5          1.5  versicolor
#   52           6.9          3.1           4.9          1.5  versicolor
#   53           5.5          2.3           4.0          1.3  versicolor
#   54           6.5          2.8           4.6          1.5  versicolor
#   55           5.7          2.8           4.5          1.3  versicolor
#   56           6.3          3.3           4.7          1.6  versicolor
#   57           4.9          2.4           3.3          1.0  versicolor
#   58           6.6          2.9           4.6          1.3  versicolor
#   59           5.2          2.7           3.9          1.4  versicolor
#   60           5.0          2.0           3.5          1.0  versicolor
#   61           5.9          3.0           4.2          1.5  versicolor
# ...

# %%
test
# Out:
# [    sepal_length  sepal_width  petal_length  petal_width species
#  0            5.1          3.5           1.4          0.2  setosa
#  1            4.9          3.0           1.4          0.2  setosa
#  2            4.7          3.2           1.3          0.2  setosa
#  3            4.6          3.1           1.5          0.2  setosa
#  4            5.0          3.6           1.4          0.2  setosa
#  5            5.4          3.9           1.7          0.4  setosa
#  6            4.6          3.4           1.4          0.3  setosa
#  7            5.0          3.4           1.5          0.2  setosa
#  8            4.4          2.9           1.4          0.2  setosa
#  9            4.9          3.1           1.5          0.1  setosa
#  10           5.4          3.7           1.5          0.2  setosa
#  11           4.8          3.4           1.6          0.2  setosa
#  12           4.8          3.0           1.4          0.1  setosa
# ...
